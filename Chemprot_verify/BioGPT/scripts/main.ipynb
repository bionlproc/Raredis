# %%
# !git clone https://github.com/microsoft/BioGPT.git
# Out:
# Cloning into 'BioGPT'...
# remote: Enumerating objects: 391, done.
# remote: Counting objects: 100% (97/97), done.
# remote: Compressing objects: 100% (49/49), done.
# remote: Total 391 (delta 71), reused 49 (delta 48), pack-reused 294
# Receiving objects: 100% (391/391), 31.45 MiB | 23.91 MiB/s, done.
# Resolving deltas: 100% (210/210), done.

# %%
# !git clone https://github.com/pytorch/fairseq
# Out:
# Cloning into 'fairseq'...
# remote: Enumerating objects: 34769, done.
# remote: Counting objects: 100% (226/226), done.
# remote: Compressing objects: 100% (140/140), done.
# remote: Total 34769 (delta 112), reused 168 (delta 80), pack-reused 34543
# Receiving objects: 100% (34769/34769), 25.04 MiB | 18.52 MiB/s, done.
# Resolving deltas: 100% (25204/25204), done.

# %%
# The colab environment comes with py3.7, but several dependencies require py>=3.8 (like NumPy).
# This can be removed if Colab ever updates python to >=3.8 in its environment.
# For the solution, see: https://stackoverflow.com/q/60775160/6578628
# For the issue tracking Colab's python update, see: https://github.com/googlecolab/colabtools/issues/1880


# !wget -O mini.sh https://repo.anaconda.com/miniconda/Miniconda3-py38_4.8.2-Linux-x86_64.sh
# !chmod +x mini.sh
# !bash ./mini.sh -b -f -p /usr/local
# !pip install ipykernel
# Out:
# --2023-07-05 16:15:25--  https://repo.anaconda.com/miniconda/Miniconda3-py38_4.8.2-Linux-x86_64.sh
# Resolving repo.anaconda.com (repo.anaconda.com)... 104.16.130.3, 104.16.131.3, 2606:4700::6810:8303, ...
# Connecting to repo.anaconda.com (repo.anaconda.com)|104.16.130.3|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 89817099 (86M) [application/x-sh]
# Saving to: ‘mini.sh’
#
# mini.sh             100%[===================>]  85.66M   198MB/s    in 0.4s
#
# 2023-07-05 16:15:25 (198 MB/s) - ‘mini.sh’ saved [89817099/89817099]
#
# PREFIX=/usr/local
# Unpacking payload ...
# done
# done
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - _libgcc_mutex==0.1=main
#     - asn1crypto==1.3.0=py38_0
#     - ca-certificates==2020.1.1=0
#     - certifi==2019.11.28=py38_0
#     - cffi==1.14.0=py38h2e261b9_0
#     - chardet==3.0.4=py38_1003
#     - conda-package-handling==1.6.0=py38h7b6447c_0
#     - conda==4.8.2=py38_0
# ...

# %%
import os
os.chdir("/content/fairseq")

# %%
# !git checkout v0.12.0
# !pip install .
# !python setup.py build_ext --inplace
# Out:
# Note: switching to 'v0.12.0'.
#
# You are in 'detached HEAD' state. You can look around, make experimental
# changes and commit them, and you can discard any commits you make in this
# state without impacting any branches by switching back to a branch.
#
# If you want to create a new branch to retain commits you create, you may
# do so (now or later) by using -c with the switch command. Example:
#
#   git switch -c <new-branch-name>
#
# Or undo this operation with:
#
#   git switch -
#
# Turn off this advice by setting config variable advice.detachedHead to false
#
# HEAD is now at 6795311b 0.12.0 release
# Processing /content/fairseq
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#     Preparing wheel metadata ... done
# ...
#      |████████████████████████████████| 619.9 MB 15 kB/s
# ...
#      |████████████████████████████████| 272 kB 82.9 MB/s
# ...

# %%
os.chdir("/content/BioGPT")

# %%
# !git clone https://github.com/moses-smt/mosesdecoder.git
# !export MOSES=${PWD}/mosesdecoder
# Out:
# Cloning into 'mosesdecoder'...
# remote: Enumerating objects: 148097, done.
# remote: Counting objects: 100% (525/525), done.
# remote: Compressing objects: 100% (229/229), done.
# remote: Total 148097 (delta 323), reused 441 (delta 292), pack-reused 147572
# Receiving objects: 100% (148097/148097), 129.88 MiB | 26.33 MiB/s, done.
# Resolving deltas: 100% (114349/114349), done.

# %%
# !git clone https://github.com/glample/fastBPE.git
# !export FASTBPE=${PWD}/fastBPE
os.chdir("fastBPE")
# !g++ -std=c++11 -pthread -O3 fastBPE/main.cc -IfastBPE -o fast
# Out:
# Cloning into 'fastBPE'...
# remote: Enumerating objects: 59, done.
# remote: Total 59 (delta 0), reused 0 (delta 0), pack-reused 59
# Unpacking objects: 100% (59/59), 29.97 KiB | 829.00 KiB/s, done.

# %%
# !pip install sacremoses
# Out:
# ...
#      |████████████████████████████████| 880 kB 4.7 MB/s
# ...
#      |████████████████████████████████| 96 kB 5.9 MB/s
# ...
#      |████████████████████████████████| 301 kB 73.0 MB/s
# ...
#   Created wheel for sacremoses: filename=sacremoses-0.0.53-py3-none-any.whl size=895254 sha256=3294d1262e5a28f01cd1d2dd60171d97e329b997aeb757067dc0add18f9926d9
#   Stored in directory: /root/.cache/pip/wheels/82/ab/9b/c15899bf659ba74f623ac776e861cf2eb8608c1825ddec66a4
# Successfully built sacremoses
# ...

# %%
# !pip install tensorboardX
# Out:
# ...
#      |████████████████████████████████| 101 kB 4.3 MB/s
# ...
#      |████████████████████████████████| 304 kB 23.0 MB/s
# ...

# %%
# %cp -av "/content/drive/MyDrive/BioGPT/pre_trained_model_med/checkpoint.pt" "/content/BioGPT/checkpoints/Pre-trained-BioGPT/"
# Out:
# '/content/drive/MyDrive/BioGPT/pre_trained_model_med/checkpoint.pt' -> '/content/BioGPT/checkpoints/Pre-trained-BioGPT/checkpoint.pt'

# %%
# %cp -av "/content/drive/MyDrive/Chemprot/bioGPT/with_ent_type/rel-is/data" "/content/BioGPT/data/Chemprot/"
# Out:
# '/content/drive/MyDrive/Chemprot/bioGPT/with_ent_type/rel-is/data' -> '/content/BioGPT/data/Chemprot/data'
# '/content/drive/MyDrive/Chemprot/bioGPT/with_ent_type/rel-is/data/relis_valid.x' -> '/content/BioGPT/data/Chemprot/data/relis_valid.x'
# '/content/drive/MyDrive/Chemprot/bioGPT/with_ent_type/rel-is/data/relis_train.pmid' -> '/content/BioGPT/data/Chemprot/data/relis_train.pmid'
# '/content/drive/MyDrive/Chemprot/bioGPT/with_ent_type/rel-is/data/relis_valid.y' -> '/content/BioGPT/data/Chemprot/data/relis_valid.y'
# '/content/drive/MyDrive/Chemprot/bioGPT/with_ent_type/rel-is/data/relis_train.x' -> '/content/BioGPT/data/Chemprot/data/relis_train.x'
# '/content/drive/MyDrive/Chemprot/bioGPT/with_ent_type/rel-is/data/relis_test.x' -> '/content/BioGPT/data/Chemprot/data/relis_test.x'
# '/content/drive/MyDrive/Chemprot/bioGPT/with_ent_type/rel-is/data/relis_valid.pmid' -> '/content/BioGPT/data/Chemprot/data/relis_valid.pmid'
# ...

# %%
# %cp -av "/content/drive/MyDrive/BioGPT/Raredis/Results/without_token_copy_instruction/wo_ent_Type/natural_language/base/RE-Raredis" "/content/BioGPT/examples/"
# Out:
# '/content/drive/MyDrive/BioGPT/Raredis/Results/without_token_copy_instruction/wo_ent_Type/natural_language/base/RE-Raredis' -> '/content/BioGPT/examples/RE-Raredis'
# '/content/drive/MyDrive/BioGPT/Raredis/Results/without_token_copy_instruction/wo_ent_Type/natural_language/base/RE-Raredis/.ipynb_checkpoints' -> '/content/BioGPT/examples/RE-Raredis/.ipynb_checkpoints'
# '/content/drive/MyDrive/BioGPT/Raredis/Results/without_token_copy_instruction/wo_ent_Type/natural_language/base/RE-Raredis/rebuild_data.py' -> '/content/BioGPT/examples/RE-Raredis/rebuild_data.py'
# '/content/drive/MyDrive/BioGPT/Raredis/Results/without_token_copy_instruction/wo_ent_Type/natural_language/base/RE-Raredis/postprocess.py' -> '/content/BioGPT/examples/RE-Raredis/postprocess.py'
# '/content/drive/MyDrive/BioGPT/Raredis/Results/without_token_copy_instruction/wo_ent_Type/natural_language/base/RE-Raredis/hard_match_evaluation.py' -> '/content/BioGPT/examples/RE-Raredis/hard_match_evaluation.py'
# ...

# %%
os.chdir("/content/BioGPT/examples/RE-Chemprot")

# %%
# !bash preprocess.sh
# Out:
# Preprocessing train
# Tokenizer Version 1.1
# Language: en
# Number of threads: 8
# Tokenizer Version 1.1
# Language: en
# Number of threads: 8
# Loading codes from /content/BioGPT/data/Chemprot/raw/bpecodes ...
# Read 40000 codes from the codes file.
# Loading vocabulary from /content/BioGPT/data/Chemprot/raw/relis_train.tok.x ...
# Read 400557 words (24062 unique) from text file.
# Applying BPE to /content/BioGPT/data/Chemprot/raw/relis_train.tok.x ...
# Modified 400557 words from text file.
# Loading codes from /content/BioGPT/data/Chemprot/raw/bpecodes ...
# Read 40000 codes from the codes file.
# Loading vocabulary from /content/BioGPT/data/Chemprot/raw/relis_train.tok.y ...
# Read 69583 words (3296 unique) from text file.
# Applying BPE to /content/BioGPT/data/Chemprot/raw/relis_train.tok.y ...
# Modified 69583 words from text file.
# Preprocessing valid
# Tokenizer Version 1.1
# Language: en
# Number of threads: 8
# Tokenizer Version 1.1
# Language: en
# Number of threads: 8
# ...

# %%
# !bash train.sh
# Out:
# Streaming output truncated to the last 5000 lines.
# epoch 046 | valid on 'valid' subset:  25% 46/187 [00:02<00:07, 20.07it/s]
# epoch 046 | valid on 'valid' subset:  26% 49/187 [00:02<00:06, 19.95it/s]
# epoch 046 | valid on 'valid' subset:  28% 52/187 [00:02<00:06, 19.79it/s]
# epoch 046 | valid on 'valid' subset:  29% 54/187 [00:03<00:06, 19.68it/s]
# epoch 046 | valid on 'valid' subset:  30% 56/187 [00:03<00:06, 19.51it/s]
# epoch 046 | valid on 'valid' subset:  31% 58/187 [00:03<00:06, 19.45it/s]
# epoch 046 | valid on 'valid' subset:  32% 60/187 [00:03<00:06, 19.31it/s]
# epoch 046 | valid on 'valid' subset:  33% 62/187 [00:03<00:06, 19.41it/s]
# epoch 046 | valid on 'valid' subset:  34% 64/187 [00:03<00:06, 19.36it/s]
# epoch 046 | valid on 'valid' subset:  35% 66/187 [00:03<00:06, 19.12it/s]
# epoch 046 | valid on 'valid' subset:  36% 68/187 [00:03<00:06, 18.95it/s]
# epoch 046 | valid on 'valid' subset:  37% 70/187 [00:03<00:06, 18.91it/s]
# ...

# %%
# !bash infer.sh
# Out:
# Begin inferencing /content/BioGPT/data/Chemprot/raw/relis_test.tok.bpe.x using /content/BioGPT/checkpoints/RE-Chemprot-BioGPT/checkpoint_best.pt
# 2023-07-05 20:48:57 | INFO | fairseq.file_utils | loading archive file /content/BioGPT/checkpoints/RE-Chemprot-BioGPT
# 2023-07-05 20:48:57 | INFO | fairseq.file_utils | loading archive file /content/BioGPT/data/Chemprot/relis-bin
# 2023-07-05 20:49:00 | INFO | src.language_modeling_prompt | dictionary: 42384 types
# ...

# %%
# %cp -av "/content/BioGPT/checkpoints/RE-Chemprot-BioGPT" "/content/drive/MyDrive/Chemprot/bioGPT/with_ent_type/rel-is"
# Out:
# '/content/BioGPT/checkpoints/RE-Chemprot-BioGPT' -> '/content/drive/MyDrive/Chemprot/bioGPT/with_ent_type/rel-is/RE-Chemprot-BioGPT'
# '/content/BioGPT/checkpoints/RE-Chemprot-BioGPT/checkpoint_best.pt' -> '/content/drive/MyDrive/Chemprot/bioGPT/with_ent_type/rel-is/RE-Chemprot-BioGPT/checkpoint_best.pt'
# '/content/BioGPT/checkpoints/RE-Chemprot-BioGPT/checkpoint_last.pt' -> '/content/drive/MyDrive/Chemprot/bioGPT/with_ent_type/rel-is/RE-Chemprot-BioGPT/checkpoint_last.pt'
# '/content/BioGPT/checkpoints/RE-Chemprot-BioGPT/checkpoint_avg.pt' -> '/content/drive/MyDrive/Chemprot/bioGPT/with_ent_type/rel-is/RE-Chemprot-BioGPT/checkpoint_avg.pt'
# '/content/BioGPT/checkpoints/RE-Chemprot-BioGPT/generate_checkpoint_avg.pt.detok' -> '/content/drive/MyDrive/Chemprot/bioGPT/with_ent_type/rel-is/RE-Chemprot-BioGPT/generate_checkpoint_avg.pt.detok'
# ...

# %%
# %cp -av "/content/BioGPT/data/Chemprot" "/content/drive/MyDrive/Chemprot/bioGPT/with_ent_type/rel-is"
# %cp -av "/content/BioGPT/examples/RE-Chemprot" "/content/drive/MyDrive/Chemprot/bioGPT/with_ent_type/rel-is"
# Out:
# '/content/BioGPT/data/Chemprot' -> '/content/drive/MyDrive/Chemprot/bioGPT/with_ent_type/rel-is/Chemprot'
# '/content/BioGPT/data/Chemprot/raw' -> '/content/drive/MyDrive/Chemprot/bioGPT/with_ent_type/rel-is/Chemprot/raw'
# '/content/BioGPT/data/Chemprot/raw/relis_valid.x' -> '/content/drive/MyDrive/Chemprot/bioGPT/with_ent_type/rel-is/Chemprot/raw/relis_valid.x'
# '/content/BioGPT/data/Chemprot/raw/relis_train.pmid' -> '/content/drive/MyDrive/Chemprot/bioGPT/with_ent_type/rel-is/Chemprot/raw/relis_train.pmid'
# '/content/BioGPT/data/Chemprot/raw/relis_valid.y' -> '/content/drive/MyDrive/Chemprot/bioGPT/with_ent_type/rel-is/Chemprot/raw/relis_valid.y'
# '/content/BioGPT/data/Chemprot/raw/relis_train.x' -> '/content/drive/MyDrive/Chemprot/bioGPT/with_ent_type/rel-is/Chemprot/raw/relis_train.x'
# '/content/BioGPT/data/Chemprot/raw/relis_test.x' -> '/content/drive/MyDrive/Chemprot/bioGPT/with_ent_type/rel-is/Chemprot/raw/relis_test.x'
# ...
